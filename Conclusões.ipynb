# %% [markdown]
# #**DESAFIO**
# ![Kyte Logo.png](data:image/png;base64,...)
# ## Nessa análise os valores foram obtidos, retirando somente as linhas que possuem todos os valores vazios.
# # **De acordo com o resultado da análise dos dados,conseguimos as seguintes informações:**

# %% [markdown]
# #**Conclusões**
#
# *   Sistema com mais usuários é o Android.
# *   Sistema Kyte web é o sistema menos utlizado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Sistema com mais usuários pagos é o IOS.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #100% dos usuários do sistema web são Trial.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Método de pagamentos mais utilizado é o Stripe.
# ##Método de pagamentos menos utilizado é o Stripe.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #O tipo de identidade mais comum é o Cpf.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
